# %% [markdown]
# # Text-to-Image Generation using Stable Diffusion
#
# This project uses a pre-trained Stable Diffusion model to generate images from text prompts. The model converts user-provided descriptions into AI-generated images using the diffusion process.
#
# Built using:
# - Python
# - Hugging Face Diffusers
# - Stable Diffusion
# - PyTorch
# - Google Colab GPU

# %% [markdown]
# ## Step 1: Check GPU Availability
#
# Google Colab GPU is used to speed up the image generation process.
# The GPU helps Stable Diffusion perform faster inference compared to CPU.

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %% [markdown]
# ## Step 2: Install Required Libraries
#
# The required Python libraries are installed for loading and running the Stable Diffusion model.
#
# - Diffusers provides access to pre-trained diffusion models.
# - Transformers helps in handling model components.
# - Accelerate improves model performance during execution.
# - Safetensors provides efficient and safe model loading.

# %%
# !pip install diffusers transformers accelerate safetensors

# %% [markdown]
# ## Step 3: Load Pre-trained Stable Diffusion Model
#
# A pre-trained Stable Diffusion model is loaded from Hugging Face using the Diffusers library.
#
# The model has already learned patterns from a large collection of image-text data, allowing it to generate images from text prompts without training from scratch.

# %%
import torch
from diffusers import StableDiffusionPipeline
model_id = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to("cuda")
print("Stable Diffusion model loaded successfully")
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# ...
# Loading weights:   0%|          | 0/396 [00:00<?, ?it/s]
# Stable Diffusion model loaded successfully

# %% [markdown]
# ## Step 4: Generate Image from Text Prompt
#
# The user enters a text prompt describing the required image. Stable Diffusion processes the text input and generates a new AI image using the pre-trained diffusion model.
#
# The generated image is displayed as the output.

# %%
prompt = input("Enter your image description: ")
image = pipe(prompt).images[0]
image
# Out:
# Enter your image description: a futuristic city with flying cars
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# ## Step 5: Save Generated Image
#
# The generated output image is saved as a PNG file so that users can download and use the AI-generated result.
#
# This step stores the final image created by the Stable Diffusion model.

# %%
image.save("generated_image.png")
print("Image saved successfully !")
# Out:
# Image saved successfully !
